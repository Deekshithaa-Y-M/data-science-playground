# %% [markdown]
# # K-Nearest Neighbors Classification
#
# This notebook classifies wine samples into the three known cultivar classes using chemical measurements from `Machine-Learning-Lab/data/wine-clustering.csv`. The train/test split and classifier are reproducible, and the evaluation uses macro-averaged multi-class metrics.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# Support execution from either the repository root or the notebook directory.
repository_data_path = Path("Machine-Learning-Lab/data/wine-clustering.csv")
notebook_data_path = Path("../data/wine-clustering.csv")
data_path = next(
    (path for path in (repository_data_path, notebook_data_path) if path.is_file()),
    repository_data_path,
)

try:
    data = pd.read_csv(data_path)
except pd.errors.EmptyDataError as error:
    raise ValueError(
        f"The input file is empty: {data_path}. "
        "Add the wine-clustering.csv data before running the notebook."
    ) from error

wine = load_wine()
if len(data) != len(wine.target):
    raise ValueError(
        f"Expected {len(wine.target)} wine samples, but found {len(data)} in {data_path}."
    )

X = data.drop(columns=["Class"], errors="ignore")
y = pd.Series(wine.target, name="Class")

print(f"Loaded {len(data)} samples with {X.shape[1]} chemical measurements from {data_path}.")
# Out:
# c:\Users\Lenovo\OneDrive\Documents\Jupyter\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\Lenovo\OneDrive\Documents\Jupyter\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[1], line 19
#      18 try:
# ---> 19     data = pd.read_csv(data_path)
#      20 except pd.errors.EmptyDataError as error:
#
# File c:\Users\Lenovo\OneDrive\Documents\Jupyter\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Lenovo\OneDrive\Documents\Jupyter\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#
# File c:\Users\Lenovo\OneDrive\Documents\Jupyter\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Lenovo\OneDrive\Documents\Jupyter\Lib\site-packages\pandas\io\parsers\readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#
# File c:\Users\Lenovo\OneDrive\Documents\Jupyter\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#
# File pandas/_libs/parsers.pyx:575, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 21
#      19     data = pd.read_csv(data_path)
#      20 except pd.errors.EmptyDataError as error:
# ---> 21     raise ValueError(
#      22         f"The input file is empty: {data_path}. "
#      23         "Add the wine-clustering.csv data before running the notebook."
#      24     ) from error
#      26 wine = load_wine()
#      27 if len(data) != len(wine.target):
#
# ValueError: The input file is empty: ..\data\wine-clustering.csv. Add the wine-clustering.csv data before running the notebook.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42,
    stratify=y,
)

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

metrics = {
    "Accuracy": accuracy_score(y_test, y_pred),
    "Precision (macro)": precision_score(y_test, y_pred, average="macro", zero_division=0),
    "Recall (macro)": recall_score(y_test, y_pred, average="macro", zero_division=0),
    "F1 score (macro)": f1_score(y_test, y_pred, average="macro", zero_division=0),
}

for metric_name, score in metrics.items():
    print(f"{metric_name}: {score:.4f}")
